# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
austin_weather = pd.read_csv('Desktop/datacamp/matplotlib/austin_weather.csv')

# %%
seattle_weather = pd.read_csv('Desktop/datacamp/matplotlib/seattle_weather.csv')

# %%
austin_weather.head()
# Out:
#        STATION                                           NAME  DATE  \
# 0  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     1
# 1  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     2
# 2  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     3
# 3  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     4
# 4  USW00013904  AUSTIN BERGSTROM INTERNATIONAL AIRPORT, TX US     5
#
#    MLY-CLDD-BASE45  MLY-CLDD-BASE50  MLY-CLDD-BASE55  MLY-CLDD-BASE57  \
# 0              190              103               50               35
# 1              228              132               68               49
# 2              446              306              185              146
# 3              668              519              373              318
# 4              936              781              626              564
#
#    MLY-CLDD-BASE60  MLY-CLDD-BASE70  MLY-CLDD-BASE72  ...  \
# 0               18                1            -7777  ...
# ...

# %%
import calendar

def numbers_to_month_names(month_numbers):
    month_names = []

    for month_number in month_numbers:
        try:
            month_name = calendar.month_name[month_number]
            month_names.append(month_name)
        except (IndexError, ValueError):
            month_names.append("Invalid month number")

    return month_names

# Example usage:
month_numbers_list = [1, 5, 9, 12, 15]  # Assuming these are month numbers
MONTH = numbers_to_month_names(seattle_weather['DATE'])
MONTH_ =numbers_to_month_names(austin_weather['DATE'])

# %%
seattle_weather['MONTH'] = MONTH
austin_weather['MONTH'] = MONTH_

# %%
seattle_weather.head()

# %%
fig, ax = plt.subplots(2,1, sharey = True)
ax[0].plot(seattle_weather['MONTH'],seattle_weather['MLY-PRCP-NORMAL'], color = 'b')
ax[0].plot(seattle_weather['MONTH'],seattle_weather['MLY-PRCP-25PCTL'], color = 'b', linestyle = '--')
ax[0].plot(seattle_weather['MONTH'],seattle_weather['MLY-PRCP-75PCTL'], color = 'b', linestyle = '--')
ax[1].plot(austin_weather['MONTH'],austin_weather['MLY-PRCP-NORMAL'], color = 'r')
ax[1].plot(austin_weather['MONTH'],austin_weather['MLY-PRCP-25PCTL'], color = 'r', linestyle = '--')
ax[1].plot(austin_weather['MONTH'],austin_weather['MLY-PRCP-75PCTL'], color = 'r', linestyle = '--')
plt.show()
