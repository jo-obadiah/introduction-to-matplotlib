# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
climate_change = pd.read_csv('Desktop/datacamp/matplotlib/climate_change.csv',index_col = 'date', parse_dates = True)

# %%
climate_change.tail(10)
# Out:
#                co2  relative_temp
# date
# 2016-03-06  404.87           1.30
# 2016-04-06  407.45           1.09
# 2016-05-06  407.72           0.93
# 2016-06-06  406.83           0.76
# 2016-07-06  404.41           0.83
# 2016-08-06  402.27           0.98
# 2016-09-06  401.05           0.87
# 2016-10-06  401.59           0.89
# 2016-11-06  403.55           0.93
# 2016-12-06  404.45           0.81

# %%
#Taking note that this is a time_series data, i will be plotting to see the change in temp relative to time.

# %%
Fig, ax = plt.subplots()
ax.plot(climate_change.index ,climate_change['relative_temp'])
ax.set_xlabel('Time')
ax.set_ylabel('Relative temperature(Celcius)')
plt.plot()
# Out:
# []
